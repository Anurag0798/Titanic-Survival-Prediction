# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
pd.pandas.set_option('display.max_columns', None)

# %%
df = pd.read_csv("titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df = df.drop(columns=['PassengerId', 'Name', 'Cabin', 'Ticket', 'Embarked'])

# %%
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare
# 0           0       3    male  22.0      1      0   7.2500
# 1           1       1  female  38.0      1      0  71.2833
# 2           1       3  female  26.0      0      0   7.9250
# 3           1       1  female  35.0      1      0  53.1000
# 4           0       3    male  35.0      0      0   8.0500
# ..        ...     ...     ...   ...    ...    ...      ...
# 886         0       2    male  27.0      0      0  13.0000
# 887         1       1  female  19.0      0      0  30.0000
# 888         0       3  female   NaN      1      2  23.4500
# 889         1       1    male  26.0      0      0  30.0000
# 890         0       3    male  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Sex'] = le.fit_transform(df['Sex'])

# %%
df
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare
# 0           0       3    1  22.0      1      0   7.2500
# 1           1       1    0  38.0      1      0  71.2833
# 2           1       3    0  26.0      0      0   7.9250
# 3           1       1    0  35.0      1      0  53.1000
# 4           0       3    1  35.0      0      0   8.0500
# ..        ...     ...  ...   ...    ...    ...      ...
# 886         0       2    1  27.0      0      0  13.0000
# 887         1       1    0  19.0      0      0  30.0000
# 888         0       3    0   NaN      1      2  23.4500
# 889         1       1    1  26.0      0      0  30.0000
# 890         0       3    1  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Sex           int32
# Age         float64
# SibSp         int64
# Parch         int64
# Fare        float64
# dtype: object

# %%
df.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# dtype: int64

# %% [markdown]
# # Approach-1 : drop rows which have null

# %%
df1 = df.copy()

# %%
df1
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare
# 0           0       3    1  22.0      1      0   7.2500
# 1           1       1    0  38.0      1      0  71.2833
# 2           1       3    0  26.0      0      0   7.9250
# 3           1       1    0  35.0      1      0  53.1000
# 4           0       3    1  35.0      0      0   8.0500
# ..        ...     ...  ...   ...    ...    ...      ...
# 886         0       2    1  27.0      0      0  13.0000
# 887         1       1    0  19.0      0      0  30.0000
# 888         0       3    0   NaN      1      2  23.4500
# 889         1       1    1  26.0      0      0  30.0000
# 890         0       3    1  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
df1.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# dtype: int64

# %%
df1 = df1.dropna()

# %%
df1
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare
# 0           0       3    1  22.0      1      0   7.2500
# 1           1       1    0  38.0      1      0  71.2833
# 2           1       3    0  26.0      0      0   7.9250
# 3           1       1    0  35.0      1      0  53.1000
# 4           0       3    1  35.0      0      0   8.0500
# ..        ...     ...  ...   ...    ...    ...      ...
# 885         0       3    0  39.0      0      5  29.1250
# 886         0       2    1  27.0      0      0  13.0000
# 887         1       1    0  19.0      0      0  30.0000
# 889         1       1    1  26.0      0      0  30.0000
# 890         0       3    1  32.0      0      0   7.7500
#
# [714 rows x 7 columns]

# %%
df1.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# dtype: int64

# %%
df1.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Sex           int32
# Age         float64
# SibSp         int64
# Parch         int64
# Fare        float64
# dtype: object

# %%
df1.shape
# Out:
# (714, 7)

# %%
df1.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
X1 = df1.drop(columns=['Survived'])
X1
# Out:
#      Pclass  Sex   Age  SibSp  Parch     Fare
# 0         3    1  22.0      1      0   7.2500
# 1         1    0  38.0      1      0  71.2833
# 2         3    0  26.0      0      0   7.9250
# 3         1    0  35.0      1      0  53.1000
# 4         3    1  35.0      0      0   8.0500
# ..      ...  ...   ...    ...    ...      ...
# 885       3    0  39.0      0      5  29.1250
# 886       2    1  27.0      0      0  13.0000
# 887       1    0  19.0      0      0  30.0000
# 889       1    1  26.0      0      0  30.0000
# 890       3    1  32.0      0      0   7.7500
#
# [714 rows x 6 columns]

# %%
y1 = df1["Survived"]

# %%
y1
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 885    0
# 886    0
# 887    1
# 889    1
# 890    0
# Name: Survived, Length: 714, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size=0.25, random_state=10)

# %%
m1 = LogisticRegression()

# %%
m1.fit(X1_train, y1_train)
# Out:
# LogisticRegression()

# %%
m1.score(X1_test, y1_test) * 100
# Out:
# 81.56424581005587

# %% [markdown]
# # Approach-2 : drop columns which have null

# %%
df2 = df.copy()

# %%
df2
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare
# 0           0       3    1  22.0      1      0   7.2500
# 1           1       1    0  38.0      1      0  71.2833
# 2           1       3    0  26.0      0      0   7.9250
# 3           1       1    0  35.0      1      0  53.1000
# 4           0       3    1  35.0      0      0   8.0500
# ..        ...     ...  ...   ...    ...    ...      ...
# 886         0       2    1  27.0      0      0  13.0000
# 887         1       1    0  19.0      0      0  30.0000
# 888         0       3    0   NaN      1      2  23.4500
# 889         1       1    1  26.0      0      0  30.0000
# 890         0       3    1  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
df2.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# dtype: int64

# %%
df2 = df2.drop(columns=['Age'])

# %%
df2.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# SibSp       0
# Parch       0
# Fare        0
# dtype: int64

# %%
df2
# Out:
#      Survived  Pclass  Sex  SibSp  Parch     Fare
# 0           0       3    1      1      0   7.2500
# 1           1       1    0      1      0  71.2833
# 2           1       3    0      0      0   7.9250
# 3           1       1    0      1      0  53.1000
# 4           0       3    1      0      0   8.0500
# ..        ...     ...  ...    ...    ...      ...
# 886         0       2    1      0      0  13.0000
# 887         1       1    0      0      0  30.0000
# 888         0       3    0      1      2  23.4500
# 889         1       1    1      0      0  30.0000
# 890         0       3    1      0      0   7.7500
#
# [891 rows x 6 columns]

# %%
X2 = df2.drop(columns=['Survived'])
X2
# Out:
#      Pclass  Sex  SibSp  Parch     Fare
# 0         3    1      1      0   7.2500
# 1         1    0      1      0  71.2833
# 2         3    0      0      0   7.9250
# 3         1    0      1      0  53.1000
# 4         3    1      0      0   8.0500
# ..      ...  ...    ...    ...      ...
# 886       2    1      0      0  13.0000
# 887       1    0      0      0  30.0000
# 888       3    0      1      2  23.4500
# 889       1    1      0      0  30.0000
# 890       3    1      0      0   7.7500
#
# [891 rows x 5 columns]

# %%
y2 = df2["Survived"]

# %%
y2
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.25, random_state=10)

# %%
m2 = LogisticRegression()

# %%
m2.fit(X2_train, y2_train)
# Out:
# LogisticRegression()

# %%
m2.score(X2_test, y2_test) * 100
# Out:
# 81.61434977578476

# %% [markdown]
# # Approach-3 : replacing null with mean in a column

# %%
df3 = df.copy()

# %%
df3
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare
# 0           0       3    1  22.0      1      0   7.2500
# 1           1       1    0  38.0      1      0  71.2833
# 2           1       3    0  26.0      0      0   7.9250
# 3           1       1    0  35.0      1      0  53.1000
# 4           0       3    1  35.0      0      0   8.0500
# ..        ...     ...  ...   ...    ...    ...      ...
# 886         0       2    1  27.0      0      0  13.0000
# 887         1       1    0  19.0      0      0  30.0000
# 888         0       3    0   NaN      1      2  23.4500
# 889         1       1    1  26.0      0      0  30.0000
# 890         0       3    1  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
df3.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# dtype: int64

# %%
df3['Age'].mean()
# Out:
# 29.69911764705882

# %%
df3["Age"] = df3["Age"].fillna(df3["Age"].mean())

# %%
df3.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# dtype: int64

# %%
df3
# Out:
#      Survived  Pclass  Sex        Age  SibSp  Parch     Fare
# 0           0       3    1  22.000000      1      0   7.2500
# 1           1       1    0  38.000000      1      0  71.2833
# 2           1       3    0  26.000000      0      0   7.9250
# 3           1       1    0  35.000000      1      0  53.1000
# 4           0       3    1  35.000000      0      0   8.0500
# ..        ...     ...  ...        ...    ...    ...      ...
# 886         0       2    1  27.000000      0      0  13.0000
# 887         1       1    0  19.000000      0      0  30.0000
# 888         0       3    0  29.699118      1      2  23.4500
# 889         1       1    1  26.000000      0      0  30.0000
# 890         0       3    1  32.000000      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
X3 = df3.drop(columns=['Survived'])
X3
# Out:
#      Pclass  Sex        Age  SibSp  Parch     Fare
# 0         3    1  22.000000      1      0   7.2500
# 1         1    0  38.000000      1      0  71.2833
# 2         3    0  26.000000      0      0   7.9250
# 3         1    0  35.000000      1      0  53.1000
# 4         3    1  35.000000      0      0   8.0500
# ..      ...  ...        ...    ...    ...      ...
# 886       2    1  27.000000      0      0  13.0000
# 887       1    0  19.000000      0      0  30.0000
# 888       3    0  29.699118      1      2  23.4500
# 889       1    1  26.000000      0      0  30.0000
# 890       3    1  32.000000      0      0   7.7500
#
# [891 rows x 6 columns]

# %%
y3 = df3['Survived']
y3
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
X3_train, X3_test, y3_train, y3_test = train_test_split(X3, y3, test_size=0.25, random_state=10)

# %%
m3 = LogisticRegression()

# %%
m3.fit(X3_train, y3_train)
# Out:
# LogisticRegression()

# %%
m3.score(X3_test, y3_test) * 100
# Out:
# 80.71748878923766

# %% [markdown]
# # Approach-4 : Removing target and applying linear regression to find exact null values in Age column

# %%
df4 = df.copy()

# %%
df4
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare
# 0           0       3    1  22.0      1      0   7.2500
# 1           1       1    0  38.0      1      0  71.2833
# 2           1       3    0  26.0      0      0   7.9250
# 3           1       1    0  35.0      1      0  53.1000
# 4           0       3    1  35.0      0      0   8.0500
# ..        ...     ...  ...   ...    ...    ...      ...
# 886         0       2    1  27.0      0      0  13.0000
# 887         1       1    0  19.0      0      0  30.0000
# 888         0       3    0   NaN      1      2  23.4500
# 889         1       1    1  26.0      0      0  30.0000
# 890         0       3    1  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
df4_new = df4.drop(columns=['Survived'])
df4_new
# Out:
#      Pclass  Sex   Age  SibSp  Parch     Fare
# 0         3    1  22.0      1      0   7.2500
# 1         1    0  38.0      1      0  71.2833
# 2         3    0  26.0      0      0   7.9250
# 3         1    0  35.0      1      0  53.1000
# 4         3    1  35.0      0      0   8.0500
# ..      ...  ...   ...    ...    ...      ...
# 886       2    1  27.0      0      0  13.0000
# 887       1    0  19.0      0      0  30.0000
# 888       3    0   NaN      1      2  23.4500
# 889       1    1  26.0      0      0  30.0000
# 890       3    1  32.0      0      0   7.7500
#
# [891 rows x 6 columns]

# %%
df4_new.isna().sum()
# Out:
# Pclass      0
# Sex         0
# Age       177
# SibSp       0
# Parch       0
# Fare        0
# dtype: int64

# %%
df4_new_test = df4_new[df4_new['Age'].isna()]
df4_new_test
# Out:
#      Pclass  Sex  Age  SibSp  Parch     Fare
# 5         3    1  NaN      0      0   8.4583
# 17        2    1  NaN      0      0  13.0000
# 19        3    0  NaN      0      0   7.2250
# 26        3    1  NaN      0      0   7.2250
# 28        3    0  NaN      0      0   7.8792
# ..      ...  ...  ...    ...    ...      ...
# 859       3    1  NaN      0      0   7.2292
# 863       3    0  NaN      8      2  69.5500
# 868       3    1  NaN      0      0   9.5000
# 878       3    1  NaN      0      0   7.8958
# 888       3    0  NaN      1      2  23.4500
#
# [177 rows x 6 columns]

# %%
df4_new_test.isna().sum()
# Out:
# Pclass      0
# Sex         0
# Age       177
# SibSp       0
# Parch       0
# Fare        0
# dtype: int64

# %%
df4_new_train = df4_new[~(df4_new['Age'].isna())]
df4_new_train
# Out:
#      Pclass  Sex   Age  SibSp  Parch     Fare
# 0         3    1  22.0      1      0   7.2500
# 1         1    0  38.0      1      0  71.2833
# 2         3    0  26.0      0      0   7.9250
# 3         1    0  35.0      1      0  53.1000
# 4         3    1  35.0      0      0   8.0500
# ..      ...  ...   ...    ...    ...      ...
# 885       3    0  39.0      0      5  29.1250
# 886       2    1  27.0      0      0  13.0000
# 887       1    0  19.0      0      0  30.0000
# 889       1    1  26.0      0      0  30.0000
# 890       3    1  32.0      0      0   7.7500
#
# [714 rows x 6 columns]

# %%
df4_new_train.isna().sum()
# Out:
# Pclass    0
# Sex       0
# Age       0
# SibSp     0
# Parch     0
# Fare      0
# dtype: int64

# %%
X4_li_reg = df4_new_train.drop(columns=['Age'])
X4_li_reg
# Out:
#      Pclass  Sex  SibSp  Parch     Fare
# 0         3    1      1      0   7.2500
# 1         1    0      1      0  71.2833
# 2         3    0      0      0   7.9250
# 3         1    0      1      0  53.1000
# 4         3    1      0      0   8.0500
# ..      ...  ...    ...    ...      ...
# 885       3    0      0      5  29.1250
# 886       2    1      0      0  13.0000
# 887       1    0      0      0  30.0000
# 889       1    1      0      0  30.0000
# 890       3    1      0      0   7.7500
#
# [714 rows x 5 columns]

# %%
y4_li_reg = df4_new_train['Age']
y4_li_reg
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 885    39.0
# 886    27.0
# 887    19.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 714, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X4_train_li_reg, X4_test_li_reg, y4_train_li_reg, y4_test_li_reg = train_test_split(X4_li_reg, y4_li_reg, test_size=0.10, random_state=10)

# %%
m4_li_reg = LinearRegression()

# %%
m4_li_reg.fit(X4_train_li_reg, y4_train_li_reg)
# Out:
# LinearRegression()

# %%
a = m4_li_reg.coef_
pd.DataFrame(a, columns=["coef"], index=X4_li_reg.columns)
# Out:
#             coef
# Pclass -7.241992
# Sex     3.409168
# SibSp  -3.686257
# Parch  -0.764329
# Fare   -0.022842

# %%
m4_li_reg.score(X4_test_li_reg, y4_test_li_reg) * 100
# Out:
# 24.015776888804474

# %%
X4_test_li_reg
# Out:
#      Pclass  Sex  SibSp  Parch     Fare
# 728       2    1      1      0  26.0000
# 555       1    1      0      0  26.5500
# 426       2    0      1      0  26.0000
# 278       3    1      4      1  29.1250
# 617       3    0      1      0  16.1000
# ..      ...  ...    ...    ...      ...
# 559       3    0      1      0  17.4000
# 238       2    1      0      0  10.5000
# 847       3    1      0      0   7.8958
# 239       2    1      0      0  12.2750
# 632       1    1      0      0  30.5000
#
# [72 rows x 5 columns]

# %%
y_pred = m4_li_reg.predict(X4_test_li_reg)
y_pred
# Out:
# array([31.36776728, 42.28345225, 27.95859915, 12.23129545, 20.94274547,
#        27.35664462, 31.94180455, 30.42284891, 21.45804767, 31.48197837,
#        30.11048799, 31.9989101 , 35.35097268, 28.18931026, 30.30648985,
#        27.95859915, 38.01586123, 28.22890268, 28.24079891, 24.83115566,
#        31.02900155, 15.31039021, 28.2311869 , 28.22652252, 24.8173544 ,
#        24.53864874, 31.9989101 , 28.22652252, 28.22490529, 28.22205002,
#        42.28345225, 28.1889288 , 42.28944834, 33.82970537, 35.35097268,
#        28.20034991, 26.38996811, 28.22833163, 42.28345225, 31.9989101 ,
#         7.37468988, 24.81573717, 24.81973455, 28.23413812, 28.20805916,
#        28.19521041, 42.0790144 , 20.18364003, 34.6066931 , 25.73414007,
#        38.34995927, 24.31308183, 20.70029713, 30.76904478, 30.41314739,
#        20.88581467, 12.69226374, 23.49278981,  8.00868797, 20.83554604,
#        30.76904478, 35.40807822, 27.11544045, 24.81640416, 20.9039137 ,
# ...

# %%
y4_test_li_reg
# Out:
# 728    25.0
# 555    62.0
# 426    28.0
# 278     7.0
# 617    26.0
#        ...
# 559    36.0
# 238    19.0
# 847    35.0
# 239    33.0
# 632    32.0
# Name: Age, Length: 72, dtype: float64

# %%
df4_new_withnull_withoutAge = df4_new_test.drop(columns=['Age'])
df4_new_withnull_withoutAge
# Out:
#      Pclass  Sex  SibSp  Parch     Fare
# 5         3    1      0      0   8.4583
# 17        2    1      0      0  13.0000
# 19        3    0      0      0   7.2250
# 26        3    1      0      0   7.2250
# 28        3    0      0      0   7.8792
# ..      ...  ...    ...    ...      ...
# 859       3    1      0      0   7.2292
# 863       3    0      8      2  69.5500
# 868       3    1      0      0   9.5000
# 878       3    1      0      0   7.8958
# 888       3    0      1      2  23.4500
#
# [177 rows x 5 columns]

# %%
y_pred_new_Age = m4_li_reg.predict(df4_new_withnull_withoutAge)
y_pred_new_Age
# Out:
# array([28.21272354, 35.35097268, 24.83172672, 28.24089485, 24.81678334,
#        28.22557229, 32.44762831, 24.81973455, 28.24079891, 28.22557229,
#        28.22205002, 24.36561893, 24.81973455, 20.53821574, 42.0790144 ,
#        42.25670858, 23.60709684, 28.22557229, 28.22205002, 24.81887797,
#        28.22205002, 28.22205002, 28.22557229, 28.22833163, 20.75886561,
#        28.22205002, 28.22890268, 20.03546343, 23.11985669, 28.23889615,
#        28.20805916, -4.20145605, 37.46009442, 42.29772864, 16.0011157 ,
#        -7.61062418, 35.30414613, 41.74780222, 20.9564508 , 28.22890268,
#        24.81973455, -4.20145605, 24.54264613, 28.22557229, 12.59194757,
#        24.824303  , 20.98033919, 20.9564508 , 28.24032379, 37.67164131,
#        28.22890268, 24.81973455, 42.18180438, 24.81973455, 35.64792152,
#        42.29601547, 42.25670858, 42.19322549, 24.81973455, 20.50233518,
#        31.95665199, 28.22205002, 36.94792444, -4.20145605, 17.09316705,
# ...

# %%
df4_new_test["Age"] = y_pred_new_Age
# Out:
# <ipython-input-175-cd902ba61302>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4_new_test["Age"] = y_pred_new_Age

# %%
df4_new_test
# Out:
#      Pclass  Sex        Age  SibSp  Parch     Fare
# 5         3    1  28.212724      0      0   8.4583
# 17        2    1  35.350973      0      0  13.0000
# 19        3    0  24.831727      0      0   7.2250
# 26        3    1  28.240895      0      0   7.2250
# 28        3    0  24.816783      0      0   7.8792
# ..      ...  ...        ...    ...    ...      ...
# 859       3    1  28.240799      0      0   7.2292
# 863       3    0  -7.610624      8      2  69.5500
# 868       3    1  28.188929      0      0   9.5000
# 878       3    1  28.225572      0      0   7.8958
# 888       3    0  19.246198      1      2  23.4500
#
# [177 rows x 6 columns]

# %%
df4_new_test.isna().sum()
# Out:
# Pclass    0
# Sex       0
# Age       0
# SibSp     0
# Parch     0
# Fare      0
# dtype: int64

# %%
df4_final = pd.concat([df4_new_train, df4_new_test])
df4_final
# Out:
#      Pclass  Sex        Age  SibSp  Parch     Fare
# 0         3    1  22.000000      1      0   7.2500
# 1         1    0  38.000000      1      0  71.2833
# 2         3    0  26.000000      0      0   7.9250
# 3         1    0  35.000000      1      0  53.1000
# 4         3    1  35.000000      0      0   8.0500
# ..      ...  ...        ...    ...    ...      ...
# 859       3    1  28.240799      0      0   7.2292
# 863       3    0  -7.610624      8      2  69.5500
# 868       3    1  28.188929      0      0   9.5000
# 878       3    1  28.225572      0      0   7.8958
# 888       3    0  19.246198      1      2  23.4500
#
# [891 rows x 6 columns]

# %%
df4_final.isna().sum()
# Out:
# Pclass    0
# Sex       0
# Age       0
# SibSp     0
# Parch     0
# Fare      0
# dtype: int64

# %%
df4_final['Survived'] = df4['Survived']
df4_final
# Out:
#      Pclass  Sex        Age  SibSp  Parch     Fare  Survived
# 0         3    1  22.000000      1      0   7.2500         0
# 1         1    0  38.000000      1      0  71.2833         1
# 2         3    0  26.000000      0      0   7.9250         1
# 3         1    0  35.000000      1      0  53.1000         1
# 4         3    1  35.000000      0      0   8.0500         0
# ..      ...  ...        ...    ...    ...      ...       ...
# 859       3    1  28.240799      0      0   7.2292         0
# 863       3    0  -7.610624      8      2  69.5500         0
# 868       3    1  28.188929      0      0   9.5000         0
# 878       3    1  28.225572      0      0   7.8958         0
# 888       3    0  19.246198      1      2  23.4500         0
#
# [891 rows x 7 columns]

# %%
df4_final.isna().sum()
# Out:
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Survived    0
# dtype: int64

# %%
X4_log_reg = df4_final.drop(columns=['Survived'])
X4_log_reg
# Out:
#      Pclass  Sex        Age  SibSp  Parch     Fare
# 0         3    1  22.000000      1      0   7.2500
# 1         1    0  38.000000      1      0  71.2833
# 2         3    0  26.000000      0      0   7.9250
# 3         1    0  35.000000      1      0  53.1000
# 4         3    1  35.000000      0      0   8.0500
# ..      ...  ...        ...    ...    ...      ...
# 859       3    1  28.240799      0      0   7.2292
# 863       3    0  -7.610624      8      2  69.5500
# 868       3    1  28.188929      0      0   9.5000
# 878       3    1  28.225572      0      0   7.8958
# 888       3    0  19.246198      1      2  23.4500
#
# [891 rows x 6 columns]

# %%
y4_log_reg = df4_final['Survived']
y4_log_reg
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 859    0
# 863    0
# 868    0
# 878    0
# 888    0
# Name: Survived, Length: 891, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
X4_train_log_reg, X4_test_log_reg, y4_train_log_reg, y4_test_log_reg = train_test_split(X4_log_reg, y4_log_reg, test_size=0.25, random_state=10)

# %%
m4_log_reg = LogisticRegression()

# %%
m4_log_reg.fit(X4_train_log_reg, y4_train_log_reg)
# Out:
# LogisticRegression()

# %%
m4_log_reg.score(X4_test_log_reg, y4_test_log_reg) * 100
# Out:
# 81.16591928251121
